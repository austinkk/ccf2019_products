# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# %%
import sys

# %%
sys.path.append("./tools/")

# %%
from mydrawtool import MyDrawTool

# %%
tr_data = pd.read_csv('./rawdata/first_round_training_data.csv', encoding='utf-8')
te_data = pd.read_csv('./rawdata/first_round_testing_data.csv', encoding='utf-8')

# %%
dict_label2id = {
    'Excellent':0, 'Good':1, 'Pass':2, 'Fail':3
}

# %%
tr_label = tr_data['Quality_label'].values

# %%
tj = map(lambda x: dict_label2id[x], tr_label)

# %%
mytool.hist(list(tj), 4)
mytool.draw()
# Out:
# No handles with labels found to put in legend.

# %%
tr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 21 columns):
# Parameter1       6000 non-null float64
# Parameter2       6000 non-null float64
# Parameter3       6000 non-null float64
# Parameter4       6000 non-null float64
# Parameter5       6000 non-null float64
# Parameter6       6000 non-null float64
# Parameter7       6000 non-null float64
# Parameter8       6000 non-null float64
# Parameter9       6000 non-null float64
# Parameter10      6000 non-null float64
# Attribute1       6000 non-null float64
# Attribute2       6000 non-null float64
# Attribute3       6000 non-null float64
# Attribute4       6000 non-null float64
# Attribute5       6000 non-null float64
# Attribute6       6000 non-null float64
# Attribute7       6000 non-null float64
# Attribute8       6000 non-null float64
# Attribute9       6000 non-null float64
# Attribute10      6000 non-null float64
# Quality_label    6000 non-null object
# ...

# %%
tr_data.describe()
# Out:
#           Parameter1    Parameter2     Parameter3     Parameter4  \
# count    6000.000000  6.000000e+03    6000.000000    6000.000000
# mean      485.198954  1.952379e+03     406.348529     189.205842
# std     11401.971393  5.419588e+04   12018.898941    2621.779049
# min         0.000003  1.683797e-07       0.000005       0.000002
# 25%         0.088221  4.765771e-02       0.102304       0.118314
# 50%         1.050304  9.405962e-01       1.044908       1.068467
# 75%        10.938565  1.569199e+01      10.665397       9.902064
# max    713682.207601  3.034568e+06  864530.632179  139767.494732
#
#          Parameter5    Parameter6    Parameter7    Parameter8    Parameter9  \
# count  6.000000e+03  6.000000e+03   6000.000000   6000.000000  6.000000e+03
# mean   5.868163e+00  5.598597e+00    272.300821     22.133231  5.823664e+04
# std    8.631865e+00  7.686898e+00   2027.460514    302.172768  3.173068e+06
# ...

# %%
a = [(i[0], i[1], i[2])for i in tr_value[:,[-3,-2,-1]]]

# %%
a
# Out:
# [(0.0354071712503914, 0.593081227289144, 1.0103849691130915),
#  (0.0354071712503914, 0.593081227289144, 1.0103849691130915),
#  (0.0354071712503914, 0.593081227289144, 1.0103849691130915),
#  (0.0354071712503914, 0.593081227289144, 1.0103849691130915),
#  (0.0354071712503914, 0.593081227289144, 1.0103849691130915),
#  (0.0354071712503914, 0.593081227289144, 1.0103849691130915),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
#  (17.85002139899382, 0.05184950759684327, 0.010191934435552328),
# ...

# %%
b = [(i[0], i[1], i[2])for i in te_value[:,[-3,-2,-1]]]

# %%
b
# Out:
# [(2.9310833859135603, 2.0058522881119365, 0.1956804776694072),
#  (0.11807690010824776, 887.6112567119349, 0.5239756752969987),
#  (0.11807690010824776, 887.6112567119349, 0.5239756752969987),
#  (17.85002139899382, 0.051849507596843265, 0.010191934435552328),
#  (17.85002139899382, 0.051849507596843265, 0.010191934435552328),
#  (17.85002139899382, 0.051849507596843265, 0.010191934435552328),
#  (17.85002139899382, 0.051849507596843265, 0.010191934435552328),
#  (17.85002139899382, 0.051849507596843265, 0.010191934435552328),
#  (17.85002139899382, 0.051849507596843265, 0.010191934435552328),
#  (17.85002139899382, 0.051849507596843265, 0.010191934435552328),
#  (17.85002139899382, 0.051849507596843265, 0.010191934435552328),
#  (14.603595301530845, 6.783966877714622, 51.94471666283621),
#  (0.0354071712503914, 0.593081227289144, 193.1491864977821),
#  (0.0354071712503914, 0.593081227289144, 193.1491864977821),
#  (0.0354071712503914, 0.593081227289144, 193.1491864977821),
# ...

# %%
tr_value = tr_data[['Parameter'+str(i) for i in range(1,11)]].values
te_value = te_data[['Parameter'+str(i) for i in range(1,11)]].values

# %%
for i in range(10):
    print (len(set(tr_value[:, i])), len(set(te_value[:, i])))
# Out:
# 6000 5675
# 6000 5675
# 6000 5675
# 6000 5675
# 132 130
# 80 76
# 14 15
# 23 23
# 16 16
# 41 41

# %%
tr_value[:, 0]
# Out:
# array([1.66012063e-03, 1.60174895e+00, 9.80387638e-02, ...,
#        4.00401161e-01, 1.33547499e-01, 3.91680752e+01])

# %%
mytool = MyDrawTool()

# %%
def getvaluelist(x, y):
    n = sorted(y)[int(len(y) * 0.9)]
    new_x = map(lambda item:item if item < n else n, x)
    return new_x

# %%
list(getvaluelist(tr_value[:,0]))
# Out:
# [0.0016601206250732926,
#  1.6017489491937518,
#  0.09803876379123562,
#  18.18185974441928,
#  0.012085347983843812,
#  0.00406202055430456,
#  0.4384492177373529,
#  102.74431421031127,
#  1.456600828055853,
#  0.00010855766956008786,
#  12.46032336018146,
#  0.7784088273040023,
#  0.0007578511404783954,
#  87.02416863426441,
#  2.8507696438113252,
#  0.0025385875862779447,
#  0.2345205537085901,
#  13.296632831997176,
#  0.22054044074434506,
#  0.20416362556184786,
#  35.59793700970824,
#  1.349669847926836,
#  0.02958795629882182,
#  41.99098553817527,
#  0.31896417497056023,
#  0.126286662542359,
#  0.18401088295418447,
#  0.05585779103612623,
#  0.0042202056302974526,
#  12.626263829665605,
#  3.0095797587408732,
#  0.038278498403930834,
#  0.8422762751061721,
#  56.252929398698285,
#  1.5395842106864523,
#  0.013144203907551834,
#  29.071992067074557,
#  3.1656898344472126,
#  0.056276444561144265,
#  1.0535548815804847,
#  0.2352070393903361,
#  4.3233234349151335,
# ...

# %%
mytool.hist(list(getvaluelist(tr_value[:,0])), 10)
mytool.draw()
# Out:
# No handles with labels found to put in legend.

# %%
mytool.hist(list(getvaluelist(te_value[:,0])), 10)
mytool.draw()
# Out:
# No handles with labels found to put in legend.

# %%
mytool.hist(list(getvaluelist(tr_value[:,2])), 10)
mytool.draw()
# Out:
# No handles with labels found to put in legend.

# %%
mytool.hist(list(getvaluelist(te_value[:,2])), 10)
mytool.draw()
# Out:
# No handles with labels found to put in legend.

# %%
group_value = te_data['Group'].values

# %%
g1 = te_value[group_value == 0]

# %%
g2 = te_value[group_value == 1]

# %%
g3 = te_value[group_value == 2]

# %%
mytool.hist(list(getvaluelist(g1[:,2], te_value[:, 2])), 10)
mytool.draw()
# Out:
# No handles with labels found to put in legend.

# %%
mytool.hist(list(getvaluelist(g2[:,2], te_value[:, 2])), 10)
mytool.draw()
# Out:
# No handles with labels found to put in legend.

# %%
mytool.hist(list(getvaluelist(g3[:,2], te_value[:, 2])), 10)
mytool.draw()
# Out:
# No handles with labels found to put in legend.
